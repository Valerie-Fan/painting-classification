# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ISPQWm6pzaN1orqr2nuk")
project = rf.workspace("sheridan-college").project("dg-e139m")
version = project.version(2)
dataset = version.download("multiclass")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 from roboflow import Roboflow
# ----> 2 rf = Roboflow(api_key="ISPQWm6pzaN1orqr2nuk")
#       3 project = rf.workspace("sheridan-college").project("dg-e139m")
#       4 version = project.version(2)
#
# File ~/.pyenv/versions/3.9.6/lib/python3.9/site-packages/roboflow/__init__.py:230, in Roboflow.__init__(self, api_key, model_format, notebook)
#     228 self.notebook = notebook
#     229 self.onboarding = False
# --> 230 self.auth()
#
# File ~/.pyenv/versions/3.9.6/lib/python3.9/site-packages/roboflow/__init__.py:233, in Roboflow.auth(self)
#     232 def auth(self):
# --> 233     r = check_key(self.api_key, self.model_format, self.notebook)
#     235     if r == "onboarding":
#     236         self.onboarding = True
#
# ...
